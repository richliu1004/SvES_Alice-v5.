# %% [markdown]
# ## Conbine metacarpal masks and trapezium masks

# %%
# sequentially conbine metacarpal mask and trapezium mask into conbined mask and save it in the folder: conbine
from utils import funcMod as fmd
fmd.combine_masks() # conbine meta and trap mask into one piece and create a folder in mask
# Out:
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\0.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\100.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\101.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\102.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\103.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\104.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\105.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\10.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\11.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\12.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\13.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\141.jpg
# img saved D:\0A_lab_data\Code\Database\training\MP\masks\combine\142.jpg
# ...

# %% [markdown]
# ## Generate yolo training data (need json label files)

# %%
# sequentially generate yolo form training data(txt) by using json files and save it in the folder: txt
from utils import funcMod as fmd
fmd.Yolo_label()
# Out:
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\0.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\1.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\10.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\100.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\101.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\102.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\103.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\104.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\105.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\11.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\12.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\13.txt
# label saved: D:\0A_lab_data\Code\Database\training\MP\labels\txt\14.txt
# ...

# %% [markdown]
# ## (For KP) Generate horizontal flipped training data

# %%
import sys
sys.path.append('utils')
from utils import KP_flip as kpf

kpf.main()
# Out:
# hint from: utils.KP_flip KPFlip complete, filepath: D:/0A_lab_data/Code/Database/training/KP\flip

# %% [markdown]
# ## Create ROI training files include image, mask, and yolo txt files

# %%
import sys
sys.path.append('utils')
from utils import ROI

ROI.main()
# Out:
# hint from utils.ROI. Choose filepath include image, mask/combine, labels/txt:
# hint from utils.ROI: Process Finished. Filepath: D:/0A_lab_data/Code/Database/training/MP\ROI

# %%
# sequentially generate yolo form training data(txt) by using json files and save it in the folder: txt
from utils import funcMod as fmd
fmd.Yolo_label()
# Out:
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P01MP02_0.txt
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P01MP02_100.txt
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P01MP02_20.txt
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P01MP02_40.txt
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P01MP02_60.txt
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P01MP02_80.txt
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P02MP01_0.txt
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P02MP01_100.txt
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P02MP01_20.txt
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P02MP01_40.txt
# label saved: D:\0A_lab_data\Code\Database\testing_sub\MP_OA\labels\txt\P02MP01_60.txt
# ...
